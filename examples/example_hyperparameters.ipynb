# %%
# !git clone https://github.com/jsaj/MDS_CPDP.git
# Out:
# Cloning into 'MDS_CPDP'...
# remote: Enumerating objects: 952, done.
# remote: Counting objects: 100% (439/439), done.
# remote: Compressing objects: 100% (285/285), done.
# remote: Total 952 (delta 204), reused 315 (delta 136), pack-reused 513
# Receiving objects: 100% (952/952), 7.73 MiB | 17.78 MiB/s, done.
# Resolving deltas: 100% (404/404), done.

# %%
# !pip install deslib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deslib in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from deslib) (1.21.6)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from deslib) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from deslib) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.0->deslib) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.0->deslib) (3.1.0)

# %%
from MDS_CPDP.mdscpdp import MDSCPDP

from deslib.des import KNORAU, KNORAE
from deslib.dcs import LCA, OLA

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

import pandas as pd
from glob import glob

import warnings
warnings.filterwarnings("ignore")

# %%
# path of datasets to predict
path = '/content/MDS_CPDP/benchmark-execution/benchmarks/datasets/RELINK/*'

# read and create dataframe (dataset) with all projects for predict
dataset = []
for project_url in glob(path):
  productName = project_url.split('/')[len(project_url.split('/'))-1].split('.csv')[0]
  df = pd.read_csv(project_url)
  df.insert(0, 'productName', productName)
  dataset.append(df)
dataset = pd.concat(dataset).reset_index(drop=True)

dataset
# Out:
#      productName  isDefective  CountLineCodeExe  AvgCyclomatic  \
# 0      Apache2.0            1               907             12
# 1      Apache2.0            0                 0              0
# 2      Apache2.0            1              1096              8
# 3      Apache2.0            0               522              5
# 4      Apache2.0            0                26              2
# ..           ...          ...               ...            ...
# 644  openintents            0                18              1
# 645  openintents            0                22              7
# 646  openintents            0                64              1
# 647  openintents            0                85              7
# 648  openintents            0                 5              1
#
#      AvgCyclomaticModified  AvgCyclomaticStrict  AvgEssential  AvgLine  \
# 0                       11                   14             4       82
# 1                        0                    0             0        0
# 2                        7                    9             4       54
# 3                        5                    6             2       37
# 4                        2                    2             1       21
# ..                     ...                  ...           ...      ...
# 644                      1                    1             1       41
# 645                      7                    7             1       50
# 646                      1                    1             1        5
# 647                      7                   11             1       21
# 648                      1                    1             1       15
#
#      AvgLineBlank  AvgLineCode  ...  CountStmtDecl  CountStmtExe  \
# 0               5           61  ...            178           738
# 1               0            0  ...              0             0
# 2               4           49  ...            172           877
# 3               5           27  ...            112           414
# 4               1            9  ...             10            20
# ..            ...          ...  ...            ...           ...
# 644             4           29  ...             13            14
# 645            10           38  ...             13            18
# 646             0            5  ...             40            66
# 647             3           17  ...             27            90
# 648             3           10  ...             10             4
#
#      MaxCyclomatic  MaxCyclomaticModified  MaxCyclomaticStrict  \
# 0               51                     51                   56
# 1                0                      0                    0
# 2               45                     26                   45
# 3               25                     25                   30
# 4                4                      5                    4
# ..             ...                    ...                  ...
# 644              1                      1                    1
# 645              7                      7                    7
# 646              6                      6                    7
# 647             19                     19                   31
# 648              1                      1                    1
#
#      RatioCommentToCode  SumCyclomatic  SumCyclomaticModified  \
# 0                  0.28            221                    197
# 1                  0.00              0                      0
# 2                  0.04            256                    217
# 3                  0.32            134                    122
# 4                  0.73              9                     10
# ..                  ...            ...                    ...
# 644                0.25              1                      1
# 645                0.27              7                      7
# 646                0.01             41                     41
# 647                0.16             47                     47
# 648                0.96              2                      2
#
#      SumCyclomaticStrict  SumEssential
# 0                    246            81
# 1                      0             0
# 2                    277           128
# 3                    146            63
# 4                      9            10
# ..                   ...           ...
# 644                    1             1
# 645                    7             1
# 646                   42            23
# 647                   71             6
# 648                    2             2
#
# [649 rows x 28 columns]

# %%
ds_algorithms = [KNORAU(), KNORAE(), OLA(), LCA()]
clf_estimators = [DecisionTreeClassifier(), LogisticRegression()]
size_pools = [25, 50]

#create MDSCPDP object to predict dataset
obj = MDSCPDP(dataset,
              dynamic_algorithm=ds_algorithms,
              base_estimator=clf_estimators,
              size_pool=size_pools)

#get MDSCPDP performance after predict the dataset. Return a pandas dataframe
obj.performances
# Out:
#    productName  percentBugs dynamic_selection              classifier  \
# 0    Apache2.0        50.52               OLA      LogisticRegression
# 1  openintents        39.29            KNORAU  DecisionTreeClassifier
# 2     zxing1.6        29.57            KNORAU  DecisionTreeClassifier
#
#   size_pool   fscore      auc       pf     gmean  precision    recall  \
# 0        25  0.75000  0.75553  0.28125  0.741663   0.735294  0.765306
# 1        25  0.50000  0.83957  0.14706  0.590703   0.642857  0.409091
# 2        25  0.33493  0.64886  0.19929  0.487339   0.384615  0.296610
#
#    accuracy   tn  fp  fn  tp
# 0  0.742268   69  27  23  75
# 1  0.678571   29   5  13   9
# 2  0.651629  225  56  83  35

# %%
# get MDSCPDP hyperparamters performances by training set. Return a pandas dataframe
obj.vector_models
# Out:
#    dynamic_selection              classifier  size_pool    fscore       auc  \
# 0             KNORAU  DecisionTreeClassifier         25  0.000000  0.421224
# 1             KNORAU  DecisionTreeClassifier         50  0.000000  0.408254
# 2             KNORAU      LogisticRegression         25  0.013986  0.543401
# 3             KNORAU      LogisticRegression         50  0.014085  0.517438
# 4             KNORAE  DecisionTreeClassifier         25  0.000000  0.409751
# 5             KNORAE  DecisionTreeClassifier         50  0.000000  0.429240
# 6             KNORAE      LogisticRegression         25  0.027027  0.566757
# 7             KNORAE      LogisticRegression         50  0.014085  0.563265
# 8                OLA  DecisionTreeClassifier         25  0.000000  0.511327
# 9                OLA  DecisionTreeClassifier         50  0.000000  0.499161
# 10               OLA      LogisticRegression         25  0.014184  0.560340
# 11               OLA      LogisticRegression         50  0.014085  0.565941
# 12               LCA  DecisionTreeClassifier         25  0.378995  0.460057
# 13               LCA  DecisionTreeClassifier         50  0.000000  0.528503
# 14               LCA      LogisticRegression         25  0.000000  0.559728
# 15               LCA      LogisticRegression         50  0.000000  0.568209
# 16            KNORAU  DecisionTreeClassifier         25  0.000000  0.517291
# 17            KNORAU  DecisionTreeClassifier         50  0.000000  0.554149
# 18            KNORAU      LogisticRegression         25  0.000000  0.457744
# 19            KNORAU      LogisticRegression         50  0.000000  0.450106
# 20            KNORAE  DecisionTreeClassifier         25  0.009217  0.592230
# 21            KNORAE  DecisionTreeClassifier         50  0.000000  0.582271
# 22            KNORAE      LogisticRegression         25  0.000000  0.450634
# 23            KNORAE      LogisticRegression         50  0.000000  0.457461
# 24               OLA  DecisionTreeClassifier         25  0.053571  0.522749
# 25               OLA  DecisionTreeClassifier         50  0.226277  0.543239
# 26               OLA      LogisticRegression         25  0.000000  0.435775
# 27               OLA      LogisticRegression         50  0.000000  0.420817
# 28               LCA  DecisionTreeClassifier         25  0.018349  0.513594
# 29               LCA  DecisionTreeClassifier         50  0.009217  0.504630
# 30               LCA      LogisticRegression         25  0.000000  0.464977
# 31               LCA      LogisticRegression         50  0.000000  0.459058
# 32            KNORAU  DecisionTreeClassifier         25  0.000000  0.501378
# 33            KNORAU  DecisionTreeClassifier         50  0.000000  0.521122
# 34            KNORAU      LogisticRegression         25  0.000000  0.386346
# 35            KNORAU      LogisticRegression         50  0.000000  0.391282
# 36            KNORAE  DecisionTreeClassifier         25  0.016529  0.501635
# 37            KNORAE  DecisionTreeClassifier         50  0.000000  0.525673
# 38            KNORAE      LogisticRegression         25  0.000000  0.652115
# 39            KNORAE      LogisticRegression         50  0.016260  0.635064
# 40               OLA  DecisionTreeClassifier         25  0.000000  0.500000
# 41               OLA  DecisionTreeClassifier         50  0.016393  0.500321
# 42               OLA      LogisticRegression         25  0.016529  0.644167
# 43               OLA      LogisticRegression         50  0.627907  0.630449
# 44               LCA  DecisionTreeClassifier         25  0.000000  0.500000
# 45               LCA  DecisionTreeClassifier         50  0.000000  0.500000
# 46               LCA      LogisticRegression         25  0.000000  0.649744
# 47               LCA      LogisticRegression         50  0.000000  0.687949
#
#          pf     gmean  precision    recall  accuracy   tn   fp   fn  tp
# 0   0.00317  0.000000   0.000000  0.000000  0.690110  314    1  140   0
# 1   0.00317  0.000000   0.000000  0.000000  0.690110  314    1  140   0
# 2   0.00635  0.084247   0.333333  0.007143  0.690110  313    2  139   1
# 3   0.00317  0.084381   0.500000  0.007143  0.692308  314    1  139   1
# 4   0.00952  0.000000   0.000000  0.000000  0.685714  312    3  140   0
# 5   0.00635  0.000000   0.000000  0.000000  0.687912  313    2  140   0
# 6   0.01905  0.118379   0.250000  0.014286  0.683516  309    6  138   2
# 7   0.00317  0.084381   0.500000  0.007143  0.692308  314    1  139   1
# 8   0.00317  0.000000   0.000000  0.000000  0.690110  314    1  140   0
# 9   0.00952  0.000000   0.000000  0.000000  0.685714  312    3  140   0
# 10  0.00000  0.084515   1.000000  0.007143  0.694505  315    0  139   1
# 11  0.00317  0.084381   0.500000  0.007143  0.692308  314    1  139   1
# 12  0.68254  0.433830   0.278523  0.592857  0.402198  100  215   57  83
# 13  0.00317  0.000000   0.000000  0.000000  0.690110  314    1  140   0
# 14  0.00000  0.000000   0.000000  0.000000  0.692308  315    0  140   0
# 15  0.00000  0.000000   0.000000  0.000000  0.692308  315    0  140   0
# 16  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 17  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 18  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 19  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 20  0.00000  0.068041   1.000000  0.004630  0.637437  377    0  215   1
# 21  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 22  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 23  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 24  0.00531  0.166224   0.750000  0.027778  0.642496  375    2  210   6
# 25  0.07162  0.365021   0.534483  0.143519  0.642496  350   27  185  31
# 26  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 27  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 28  0.00000  0.096225   1.000000  0.009259  0.639123  377    0  214   2
# 29  0.00000  0.068041   1.000000  0.004630  0.637437  377    0  215   1
# 30  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 31  0.00000  0.000000   0.000000  0.000000  0.635750  377    0  216   0
# 32  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 33  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 34  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 35  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 36  0.00000  0.091287   1.000000  0.008333  0.524000  130    0  119   1
# 37  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 38  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 39  0.01538  0.090582   0.333333  0.008333  0.516000  128    2  119   1
# 40  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 41  0.00769  0.090935   0.500000  0.008333  0.520000  129    1  119   1
# 42  0.00000  0.091287   1.000000  0.008333  0.524000  130    0  119   1
# 43  0.43846  0.615661   0.586957  0.675000  0.616000   73   57   39  81
# 44  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 45  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 46  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
# 47  0.00000  0.000000   0.000000  0.000000  0.520000  130    0  120   0
